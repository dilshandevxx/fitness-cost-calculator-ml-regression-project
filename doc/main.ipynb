# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('../data/smartwatches.csv',index_col=0)

# %%
df.head()
# Out:
#         Brand  Current Price  Original Price  Discount Percentage  Rating  \
# 0       noise        82990.0         89900.0             7.686318     4.0
# 1  fire-boltt         3799.0         16999.0            77.651627     4.3
# 2        boat         1999.0          7990.0            74.981227     3.8
# 3  fire-boltt         1799.0         19999.0            91.004550     4.3
# 4       noise         1599.0          4999.0            68.013603     4.1
#
#    Number OF Ratings Dial Shape Strap Color Strap Material Touchscreen  \
# 0               65.0     Circle       Black        Silicon         Yes
# 1            20788.0     Circle       Black        Silicon         Yes
# 2            21724.0     Circle       Black        Silicon         Yes
# 3            13244.0     Circle       Black        Silicon         Yes
# 4            13901.0     Circle       Black          Other         Yes
#
#    Battery Life (Days) Bluetooth  Display Size  Weight
# 0                  8.0       Yes           NaN     NaN
# 1                  3.5       Yes           NaN     NaN
# 2                  8.0       Yes           NaN     NaN
# 3                  3.5       Yes           NaN     NaN
# 4                  8.0       Yes           NaN     NaN

# %%
df.tail()
# Out:
#           Brand  Current Price  Original Price  Discount Percentage    Rating  \
# 445  fire-boltt         5999.0          8999.0            33.337037  2.500000
# 446  fire-boltt         3700.0          9999.0            62.996300  4.031306
# 447  fire-boltt         5999.0          8999.0            33.337037  2.500000
# 448  fire-boltt         3200.0          7999.0            59.994999  4.031306
# 449  fire-boltt         3000.0          7999.0            62.495312  4.031306
#
#      Number OF Ratings Dial Shape Strap Color Strap Material Touchscreen  \
# 445       11594.726343     Circle        Grey        Silicon         Yes
# 446       11594.726343     Square       Black        Silicon         Yes
# 447       11594.726343     Circle        Gold        Silicon         Yes
# 448       11594.726343     Square        Blue        Silicon         Yes
# 449       11594.726343     Square       Black        Silicon         Yes
#
#      Battery Life (Days) Bluetooth  Display Size  Weight
# 445                 22.0       Yes           NaN     NaN
# 446                  8.0       Yes           NaN     NaN
# 447                 22.0       Yes           NaN     NaN
# 448                 22.0       Yes           NaN     NaN
# 449                 22.0       Yes           NaN     NaN

# %%
df.isnull().sum()
# Out:
# Brand                    0
# Current Price           10
# Original Price          73
# Discount Percentage     73
# Rating                   6
# Number OF Ratings       59
# Model Name              35
# Dial Shape             123
# Strap Color            123
# Strap Material          69
# Touchscreen             37
# Battery Life (Days)     32
# Bluetooth                6
# Display Size            30
# Weight                 186
# dtype: int64

# %%
##data pre-processing

# %%
num_cols = [
    "Original Price", "Discount Percentage", "Rating",
    "Number OF Ratings", "Battery Life (Days)",
    "Display Size", "Weight"
]

df[num_cols].dtypes
# Out:
# Original Price         float64
# Discount Percentage    float64
# Rating                 float64
# Number OF Ratings      float64
# Battery Life (Days)    float64
# Display Size            object
# Weight                  object
# dtype: object

# %%
df[["Display Size","Weight"]].dtypes
# Out:
# Display Size    object
# Weight          object
# dtype: object

# %%
df["Display Size"]=(df["Display Size"].astype("str").str.replace("inch","",regex=False).str.strip())
df["Display Size"]=pd.to_numeric(df["Display Size"],errors="coerce")

# %%
df[["Display Size"]].dtypes
# Out:
# Display Size    float64
# dtype: object

# %%
df["Weight"]=(df["Weight"].astype("str").str.replace("g","",regex=False).str.strip())
df["Weight"]=pd.to_numeric(df["Weight"],errors="coerce")

# %%
df[["Weight"]].dtypes
# Out:
# Weight    float64
# dtype: object

# %%
df[num_cols].dtypes
# Out:
# Original Price         float64
# Discount Percentage    float64
# Rating                 float64
# Number OF Ratings      float64
# Battery Life (Days)    float64
# Display Size           float64
# Weight                 float64
# dtype: object

# %%
df.dtypes
# Out:
# Brand                   object
# Current Price          float64
# Original Price         float64
# Discount Percentage    float64
# Rating                 float64
# Number OF Ratings      float64
# Dial Shape              object
# Strap Color             object
# Strap Material          object
# Touchscreen              int64
# Battery Life (Days)    float64
# Bluetooth                int64
# Display Size           float64
# Weight                 float64
# dtype: object

# %%
#df.drop(columns=["Model Name"],inplace=True)

# %%
num_cols=df.select_dtypes(include='number').columns

# %%
df[num_cols]=df[num_cols].fillna(df[num_cols].mean()[0])
df.head()
# Out:
# C:\Users\dilsh\AppData\Local\Temp\ipykernel_29336\2311277182.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df[num_cols]=df[num_cols].fillna(df[num_cols].mean()[0])
#         Brand  Current Price  Original Price  Discount Percentage  Rating  \
# 0       noise        82990.0         89900.0             7.686318     4.0
# 1  fire-boltt         3799.0         16999.0            77.651627     4.3
# 2        boat         1999.0          7990.0            74.981227     3.8
# 3  fire-boltt         1799.0         19999.0            91.004550     4.3
# 4       noise         1599.0          4999.0            68.013603     4.1
#
#    Number OF Ratings Dial Shape Strap Color Strap Material  Touchscreen  \
# 0               65.0     Circle       Black        Silicon            1
# 1            20788.0     Circle       Black        Silicon            1
# 2            21724.0     Circle       Black        Silicon            1
# 3            13244.0     Circle       Black        Silicon            1
# 4            13901.0     Circle       Black          Other            1
#
#    Battery Life (Days)  Bluetooth  Display Size        Weight
# 0                  8.0          1  12747.554545  12747.554545
# 1                  3.5          1  12747.554545  12747.554545
# 2                  8.0          1  12747.554545  12747.554545
# 3                  3.5          1  12747.554545  12747.554545
# 4                  8.0          1  12747.554545  12747.554545

# %%
cato_columns=df.select_dtypes(include='object').columns

# %%
for col in cato_columns:
    df[col]=df[col].fillna(df[col].mode()[0])

# %%
binary_col=["Touchscreen","Bluetooth"]
binary_col
# Out:
# ['Touchscreen', 'Bluetooth']

# %%
for col in binary_col:
    df[col]=df[col].map({"Yes":1,"No":0})

# %%
df.head()
# Out:
#    Current Price  Original Price  Discount Percentage  Rating  \
# 0        82990.0         89900.0             7.686318     4.0
# 1         3799.0         16999.0            77.651627     4.3
# 2         1999.0          7990.0            74.981227     3.8
# 3         1799.0         19999.0            91.004550     4.3
# 4         1599.0          4999.0            68.013603     4.1
#
#    Number OF Ratings  Touchscreen  Battery Life (Days)  Bluetooth  \
# 0               65.0          NaN                  8.0        NaN
# 1            20788.0          NaN                  3.5        NaN
# 2            21724.0          NaN                  8.0        NaN
# 3            13244.0          NaN                  3.5        NaN
# 4            13901.0          NaN                  8.0        NaN
#
#    Display Size        Weight  ...  Strap Material_Metal  \
# 0  12747.554545  12747.554545  ...                 False
# 1  12747.554545  12747.554545  ...                 False
# 2  12747.554545  12747.554545  ...                 False
# 3  12747.554545  12747.554545  ...                 False
# 4  12747.554545  12747.554545  ...                 False
#
#    Strap Material_Nylon  Strap Material_Other  Strap Material_Plastic  \
# 0                 False                 False                   False
# 1                 False                 False                   False
# 2                 False                 False                   False
# 3                 False                 False                   False
# 4                 False                  True                   False
#
#    Strap Material_Polycarbonate  Strap Material_Rubber  \
# 0                         False                  False
# 1                         False                  False
# 2                         False                  False
# 3                         False                  False
# 4                         False                  False
#
#    Strap Material_Silicon  Strap Material_Stainless Steel  \
# 0                    True                           False
# 1                    True                           False
# 2                    True                           False
# 3                    True                           False
# 4                   False                           False
#
#    Strap Material_Synthetic  Strap Material_Thermo Plastic Polyurethene
# 0                     False                                       False
# 1                     False                                       False
# 2                     False                                       False
# 3                     False                                       False
# 4                     False                                       False
#
# [5 rows x 75 columns]
