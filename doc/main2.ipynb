# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('../data/smartwatches.csv',index_col=0)

# %%
df.head()
# Out:
#         Brand  Current Price  Original Price  Discount Percentage  Rating  \
# 0       noise        82990.0         89900.0             7.686318     4.0
# 1  fire-boltt         3799.0         16999.0            77.651627     4.3
# 2        boat         1999.0          7990.0            74.981227     3.8
# 3  fire-boltt         1799.0         19999.0            91.004550     4.3
# 4       noise         1599.0          4999.0            68.013603     4.1
#
#    Number OF Ratings                              Model Name Dial Shape  \
# 0               65.0   Wrb-sw-colorfitpro4alpha-std-rgld_pnk        NaN
# 1            20788.0                                  BSW046        NaN
# 2            21724.0                               Wave Call        NaN
# 3            13244.0                                  BSW053        NaN
# 4            13901.0  Wrb-sw-colorfitpulsegobuzz-std-blk_blk        NaN
#
#   Strap Color Strap Material Touchscreen  Battery Life (Days) Bluetooth  \
# 0         NaN            NaN         NaN                  8.0       Yes
# 1         NaN        Silicon         Yes                  3.5       Yes
# 2         NaN        Silicon         Yes                  8.0       Yes
# 3         NaN        Silicon         Yes                  3.5       Yes
# 4         NaN          Other         Yes                  8.0       Yes
#
#   Display Size     Weight
# 0          NaN  35 - 50 g
# 1   1.8 inches  50 - 75 g
# 2   1.7 inches  35 - 50 g
# 3   1.8 inches      75g +
# 4   1.7 inches  35 - 50 g

# %%
df.tail()
# Out:
#           Brand  Current Price  Original Price  Discount Percentage  Rating  \
# 445  fire-boltt         5999.0          8999.0            33.337037     2.5
# 446  fire-boltt         3700.0          9999.0            62.996300     NaN
# 447  fire-boltt         5999.0          8999.0            33.337037     2.5
# 448  fire-boltt         3200.0          7999.0            59.994999     NaN
# 449  fire-boltt         3000.0          7999.0            62.495312     NaN
#
#      Number OF Ratings Model Name Dial Shape Strap Color Strap Material  \
# 445                NaN     bsw003     Circle        Grey        Silicon
# 446                NaN  beast pro     Square       Black        Silicon
# 447                NaN     bsw003     Circle        Gold        Silicon
# 448                NaN     call 2     Square        Blue        Silicon
# 449                NaN     call 2     Square       Black        Silicon
#
#     Touchscreen  Battery Life (Days) Bluetooth Display Size Weight
# 445         Yes                 22.0       Yes   1.3 inches    NaN
# 446         Yes                  8.0       Yes   0.1 inches    NaN
# 447         Yes                 22.0       Yes   1.3 inches    NaN
# 448         Yes                 22.0       Yes   0.1 inches    NaN
# 449         Yes                 22.0       Yes   0.1 inches    NaN

# %%
df.isnull().sum()
# Out:
# Brand                    0
# Current Price           10
# Original Price          73
# Discount Percentage     73
# Rating                   6
# Number OF Ratings       59
# Model Name              35
# Dial Shape             123
# Strap Color            123
# Strap Material          69
# Touchscreen             37
# Battery Life (Days)     32
# Bluetooth                6
# Display Size            30
# Weight                 186
# dtype: int64

# %%
##data pre-processing

# %%
num_cols = [
    "Original Price", "Discount Percentage", "Rating",
    "Number OF Ratings", "Battery Life (Days)",
    "Display Size", "Weight"
]

df[num_cols].dtypes
# Out:
# Original Price         float64
# Discount Percentage    float64
# Rating                 float64
# Number OF Ratings      float64
# Battery Life (Days)    float64
# Display Size            object
# Weight                  object
# dtype: object

# %%
df[["Display Size","Weight"]].dtypes
# Out:
# Display Size    object
# Weight          object
# dtype: object

# %%
df["Display Size"]=(df["Display Size"].astype("str").str.replace("inch","",regex=False).str.strip())
df["Display Size"]=pd.to_numeric(df["Display Size"],errors="coerce")

# %%
df["Weight"]=(df["Weight"].astype("str").str.replace("g","",regex=False).str.strip())
df["Weight"]=pd.to_numeric(df["Weight"],errors="coerce")

# %%
df[["Weight"]].dtypes
# Out:
# Weight    float64
# dtype: object

# %%
df[num_cols].dtypes
# Out:
# Original Price         float64
# Discount Percentage    float64
# Rating                 float64
# Number OF Ratings      float64
# Battery Life (Days)    float64
# Display Size           float64
# Weight                 float64
# dtype: object

# %%
df.dtypes
# Out:
# Brand                   object
# Current Price          float64
# Original Price         float64
# Discount Percentage    float64
# Rating                 float64
# Number OF Ratings      float64
# Model Name              object
# Dial Shape              object
# Strap Color             object
# Strap Material          object
# Touchscreen             object
# Battery Life (Days)    float64
# Bluetooth               object
# Display Size           float64
# Weight                 float64
# dtype: object

# %%
num_cols=df.select_dtypes(include='number').columns

# %%
df[num_cols]=df[num_cols].fillna(df[num_cols].mean()[0])
df.head()
# Out:
# C:\Users\dilsh\AppData\Local\Temp\ipykernel_15240\2311277182.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df[num_cols]=df[num_cols].fillna(df[num_cols].mean()[0])
#    Current Price  Original Price  Discount Percentage  Rating  \
# 0        82990.0         89900.0             7.686318     4.0
# 1         3799.0         16999.0            77.651627     4.3
# 2         1999.0          7990.0            74.981227     3.8
# 3         1799.0         19999.0            91.004550     4.3
# 4         1599.0          4999.0            68.013603     4.1
#
#    Number OF Ratings  Touchscreen  Battery Life (Days)  Bluetooth  \
# 0               65.0            1                  8.0          1
# 1            20788.0            1                  3.5          1
# 2            21724.0            1                  8.0          1
# 3            13244.0            1                  3.5          1
# 4            13901.0            1                  8.0          1
#
#    Display Size        Weight  ...  Strap Material_Metal  \
# 0  12747.554545  12747.554545  ...                 False
# 1  12747.554545  12747.554545  ...                 False
# 2  12747.554545  12747.554545  ...                 False
# 3  12747.554545  12747.554545  ...                 False
# 4  12747.554545  12747.554545  ...                 False
#
#    Strap Material_Nylon  Strap Material_Other  Strap Material_Plastic  \
# 0                 False                 False                   False
# 1                 False                 False                   False
# 2                 False                 False                   False
# 3                 False                 False                   False
# 4                 False                  True                   False
#
#    Strap Material_Polycarbonate  Strap Material_Rubber  \
# 0                         False                  False
# 1                         False                  False
# 2                         False                  False
# 3                         False                  False
# 4                         False                  False
#
#    Strap Material_Silicon  Strap Material_Stainless Steel  \
# 0                    True                           False
# 1                    True                           False
# 2                    True                           False
# 3                    True                           False
# 4                   False                           False
#
#    Strap Material_Synthetic  Strap Material_Thermo Plastic Polyurethene
# 0                     False                                       False
# 1                     False                                       False
# 2                     False                                       False
# 3                     False                                       False
# 4                     False                                       False
#
# [5 rows x 468 columns]

# %%
cato_columns=df.select_dtypes(include='object').columns

# %%
for col in cato_columns:
    df[col]=df[col].fillna(df[col].mode()[0])

# %%
binary_col=["Touchscreen","Bluetooth"]
binary_col
# Out:
# ['Touchscreen', 'Bluetooth']

# %%
for col in binary_col:
    df[col]=df[col].map({"Yes":1,"No":0})

# %%
df.head()
# Out:
#    Current Price  Original Price  Discount Percentage  Rating  \
# 0        82990.0         89900.0             7.686318     4.0
# 1         3799.0         16999.0            77.651627     4.3
# 2         1999.0          7990.0            74.981227     3.8
# 3         1799.0         19999.0            91.004550     4.3
# 4         1599.0          4999.0            68.013603     4.1
#
#    Number OF Ratings  Touchscreen  Battery Life (Days)  Bluetooth  \
# 0               65.0            1                  8.0          1
# 1            20788.0            1                  3.5          1
# 2            21724.0            1                  8.0          1
# 3            13244.0            1                  3.5          1
# 4            13901.0            1                  8.0          1
#
#    Display Size        Weight  ...  Strap Material_Metal  \
# 0  12747.554545  12747.554545  ...                 False
# 1  12747.554545  12747.554545  ...                 False
# 2  12747.554545  12747.554545  ...                 False
# 3  12747.554545  12747.554545  ...                 False
# 4  12747.554545  12747.554545  ...                 False
#
#    Strap Material_Nylon  Strap Material_Other  Strap Material_Plastic  \
# 0                 False                 False                   False
# 1                 False                 False                   False
# 2                 False                 False                   False
# 3                 False                 False                   False
# 4                 False                  True                   False
#
#    Strap Material_Polycarbonate  Strap Material_Rubber  \
# 0                         False                  False
# 1                         False                  False
# 2                         False                  False
# 3                         False                  False
# 4                         False                  False
#
#    Strap Material_Silicon  Strap Material_Stainless Steel  \
# 0                    True                           False
# 1                    True                           False
# 2                    True                           False
# 3                    True                           False
# 4                   False                           False
#
#    Strap Material_Synthetic  Strap Material_Thermo Plastic Polyurethene
# 0                     False                                       False
# 1                     False                                       False
# 2                     False                                       False
# 3                     False                                       False
# 4                     False                                       False
#
# [5 rows x 468 columns]

# %%
df=pd.get_dummies(df,columns=["Brand","Model Name","Dial Shape","Strap Color","Strap Material"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df=pd.get_dummies(df,columns=["Brand","Model Name","Dial Shape","Strap Color","Strap Material"])
#
# File c:\programs\Lib\site-packages\pandas\core\reshape\encoding.py:169, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167     raise TypeError("Input must be a list-like for parameter `columns`")
#     168 else:
# --> 169     data_to_encode = data[columns]
#     171 # validate prefixes and separator to avoid silently dropping cols
#     172 def check_len(item, name: str):
#
# File c:\programs\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\programs\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\programs\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Brand', 'Model Name', 'Dial Shape', 'Strap Color', 'Strap Material'], dtype='object')] are in the [columns]"

# %%
df.head()
# Out:
#    Current Price  Original Price  Discount Percentage  Rating  \
# 0        82990.0         89900.0             7.686318     4.0
# 1         3799.0         16999.0            77.651627     4.3
# 2         1999.0          7990.0            74.981227     3.8
# 3         1799.0         19999.0            91.004550     4.3
# 4         1599.0          4999.0            68.013603     4.1
#
#    Number OF Ratings  Touchscreen  Battery Life (Days)  Bluetooth  \
# 0               65.0            1                  8.0          1
# 1            20788.0            1                  3.5          1
# 2            21724.0            1                  8.0          1
# 3            13244.0            1                  3.5          1
# 4            13901.0            1                  8.0          1
#
#    Display Size        Weight  ...  Strap Material_Metal  \
# 0  12747.554545  12747.554545  ...                 False
# 1  12747.554545  12747.554545  ...                 False
# 2  12747.554545  12747.554545  ...                 False
# 3  12747.554545  12747.554545  ...                 False
# 4  12747.554545  12747.554545  ...                 False
#
#    Strap Material_Nylon  Strap Material_Other  Strap Material_Plastic  \
# 0                 False                 False                   False
# 1                 False                 False                   False
# 2                 False                 False                   False
# 3                 False                 False                   False
# 4                 False                  True                   False
#
#    Strap Material_Polycarbonate  Strap Material_Rubber  \
# 0                         False                  False
# 1                         False                  False
# 2                         False                  False
# 3                         False                  False
# 4                         False                  False
#
#    Strap Material_Silicon  Strap Material_Stainless Steel  \
# 0                    True                           False
# 1                    True                           False
# 2                    True                           False
# 3                    True                           False
# 4                   False                           False
#
#    Strap Material_Synthetic  Strap Material_Thermo Plastic Polyurethene
# 0                     False                                       False
# 1                     False                                       False
# 2                     False                                       False
# 3                     False                                       False
# 4                     False                                       False
#
# [5 rows x 468 columns]

# %%
print(df.columns.tolist())
# Out:
# ['Current Price', 'Original Price', 'Discount Percentage', 'Rating', 'Number OF Ratings', 'Touchscreen', 'Battery Life (Days)', 'Bluetooth', 'Display Size', 'Weight', 'Brand_amazfit', 'Brand_ambrane', 'Brand_apple', 'Brand_boat', 'Brand_crossbeats', 'Brand_dizo', 'Brand_fire-boltt', 'Brand_fitbit', 'Brand_fossil', 'Brand_garmin', 'Brand_gizmore', 'Brand_hammer', 'Brand_honor', 'Brand_huawei', 'Brand_noise', 'Brand_pebble', 'Brand_samsung', 'Brand_zebronics', 'Model Name_4th Gen Explorist HR', 'Model Name_4th Gen Venture HR', 'Model Name_7.54E+11', 'Model Name_8.90E+12', 'Model Name_910', 'Model Name_ARG-B39-cr', 'Model Name_Apple Watch SE', 'Model Name_Approach S62', 'Model Name_Aspire Unisex 2.5D Curved Screen Smartwatch with Female Cycle Tracker Rose Gold', 'Model Name_BSW003', 'Model Name_BSW005', 'Model Name_BSW019', 'Model Name_BSW024', 'Model Name_BSW030', 'Model Name_BSW037', 'Model Name_BSW042', 'Model Name_BSW043', 'Model Name_BSW046', 'Model Name_BSW049', 'Model Name_BSW053', 'Model Name_BSW070', 'Model Name_BSW072', 'Model Name_BSW073', 'Model Name_BSW100', 'Model Name_Bip 3 Pro with 1.69 inch Large Color Display Built-in GPS', 'Model Name_Bip Lite', 'Model Name_Bip U', 'Model Name_Bip U pro 1.43 HD display GLONASS GPS & AI assistant', 'Model Name_Blaze', 'Model Name_Blaze Max 1.85" BT Calling Edge to Edge Display, Voice Assistance, Bluetooth', 'Model Name_BoAt Wave Call Plus', 'Model Name_COSMOS', 'Model Name_Caliber Buzz Advanced BT Calling(True Sync), 1.69" display, 500 NITS Brightness', 'Model Name_Charge 5', 'Model Name_Charter Hybrid HR Smartwatch', 'Model Name_Collider Hybrid HR', 'Model Name_ColorFit Brio', 'Model Name_ColorFit Caliber 2 Buzz Advanced BT Calling, 1.85" display,10 days battery', "Model Name_ColorFit Caliber 2 with 1.83'' display Up to 12 Day Battery, 60 sports mode", 'Model Name_ColorFit Caliber Go with 1.69 inch HD Display, 40 Sports Modes, 150+ Watch Faces', 'Model Name_ColorFit Caliber Smart Watch with 15-day battery, 1.69" display, 60 Sports Modes', 'Model Name_ColorFit Icon 2 1.8 Display, Bluetooth Calling, AI Voice Assistance', 'Model Name_ColorFit Loop Advanced BT Calling with 1.85" display,130+Sports Modes', 'Model Name_ColorFit Pro 2', 'Model Name_ColorFit Pro 3', 'Model Name_ColorFit Pro4 BT Calling 1.72" TruView Display, Fully-functional digital crown', 'Model Name_ColorFit Pro4 Max 1.8" BT Calling, Noise detection, Noise Health Suite', 'Model Name_ColorFit Vision 2 Buzz', 'Model Name_Commuter', 'Model Name_Core 2 1.28" Display , Noisefit sync app, 100+ watch faces & 50+ Sports Modes', 'Model Name_Cosmos', 'Model Name_Cosmos Grande 2.1 Largest Display, BT Calling, Wireless Charging,GPS Trajectory', 'Model Name_Cosmos Luxe 2.0 1.43" AMOLED Display with BT Calling and Responsive Watch Faces', 'Model Name_Cosmos Pro 1.7inch HD LCD display with Bluetooth calling function', 'Model Name_Cosmos Pro 1.7inch HD display with Bluetooth calling function', 'Model Name_Cosmos Ultra 1.91" 600 nits BT-Calling High-Res Curved Display, Ultra-Thin Dial', 'Model Name_Cosmos luxe 1.36" AMOLED Always-on Display Bluetooth calling', 'Model Name_Cosmos luxe 1.36" AMOLED Always-on Display Bluetooth calling(Midnight Gold)', 'Model Name_D TALK SMART WATCH (SILVER GREY)', 'Model Name_D Talk DW 32051 Smart Watch with Up to 7 Day Battery Life, Classic Black', 'Model Name_DAZZLE PLUS', 'Model Name_Epix Gen 2, Sapphire, Up to 16 days Battery, AMOLED Display, Real Time Stamina', 'Model Name_Epix Gen 2, Up to 16 days Battery, AMOLED Display, Real Time Stamina', 'Model Name_Evolve 3, 1.43" AMOLED AOD, 466*466px, 500 nits, BT calling,Tru Sync Technology', 'Model Name_FB-01 Hybrid HR', 'Model Name_FIT380CH', 'Model Name_FIT7220CH', 'Model Name_FTW1140 Q Hybrid Watch', 'Model Name_FTW4003 Smart Watch', 'Model Name_Fb-01 Hybrid Smartwatch Hr', 'Model Name_Fenix 6 Sapphire Carbon Gray DLC, Wrist-Based Heart Rate and Pulse OX, Sensors', 'Model Name_Fenix 6S Sapphire, Premium GPS Watch, Music, Pace Guidance and Pulse Ox Sen ...
